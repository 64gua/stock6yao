# %% [markdown]
# <a href="https://colab.research.google.com/github/64gua/stock6yao/blob/main/sql_demo_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/iching')
os.listdir()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['sixyaoUI.spec',
#  'sixyaoUI.exe',
#  'ichingshifa_ex1.py',
#  'stocknames.csv',
#  'indexnames.csv',
#  'etfnames.csv',
#  'JQindexs.csv',
#  'JQindexList.py',
#  'JQindexETF.csv',
#  'allstocks.csv',
#  'ichingDatabase.py',
#  'pdf_ocr修改名字.py',
#  'PIL_Image_test1.py',
#  'tessOCR.py',
#  'pdf提取文字v2.py',
#  'log.txt',
#  'sixyaoUI.py',
#  'insertCSVtoDB.py',
#  'plotlyjk.py',
#  'plotlyjk_another.py',
#  'part1_treated_v1.csv',
#  'part2_treated_v1.csv',
#  'part3_treated_v1.csv',
#  'part4_treated_v1.csv',
#  'part5_treated_v1.csv',
#  'md2Candle.ui',
#  'md2Candle_ui.py',
#  'db_search_2.ui',
#  'bugua.ui',
#  '002029_2015-06-24_15d.jpg',
#  'sixyao.py',
#  '__pycache__',
#  'sixyao.ipynb',
#  'plot_demo2.ipynb',
#  'Guas.db',
#  'ichingDatabaseAK.py',
#  'data',
#  'temp100.jpg',
#  'akshare_plotly.py',
#  'my_visualisation.html',
#  'temp300.png',
#  'sqlite_demo.ipynb',
#  'plotly_demo.ipynb',
#  'Guas_2024-07-07.db',
#  'Guas.zip',
#  '.ipynb_checkpoints',
#  'current_record_content.html',
#  'current_record.html',
#  'akshare_plotly (1).ipynb',
#  'akshare_plotly.ipynb',
#  'sql-demo_v2.ipynb']

# %%
# !python akshare_plotly.py
# Out:
# 中国石化
# 2024-12-25 00:00:00 3406.21
# pic is OK!

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
** test **
# Out:
#   File "<ipython-input-15-494130bd6843>", line 1
#     ** test **
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ** test image **

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from IPython.display import HTML

# image=Image.open("Save_icon.png")
# image_np=np.array(image)
# plt.imshow(image_np)
# plt.text(10,10,"this is TEXT",fontsize=12)
# plt.savefig("output.png")
def demo_html():
    html_content=f'<br> <h>hello, are you OK!</h><br><img alt="picture" src="taiji.png "> '
    html=HTML(html_content)
    html
    # html=HTML(filename="gou2jian.html")
    return html

html=demo_html()
print("fine, finished")
html

# %%
# !pip install sxtwl
# Out:
# Collecting sxtwl
#   Downloading sxtwl-2.0.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.6 kB)
# Downloading sxtwl-2.0.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.6 MB/s eta 0:00:00
# Installing collected packages: sxtwl
# Successfully installed sxtwl-2.0.7

# %%
# !pip install akshare
# Out:
# Collecting akshare
#   Downloading akshare-1.15.68-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: beautifulsoup4>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from akshare) (4.12.3)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from akshare) (5.3.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from akshare) (2.2.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from akshare) (2.32.3)
# Requirement already satisfied: html5lib>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from akshare) (1.1)
# Requirement already satisfied: xlrd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from akshare) (2.0.1)
# Requirement already satisfied: urllib3>=1.25.8 in /usr/local/lib/python3.10/dist-packages (from akshare) (2.3.0)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.10/dist-packages (from akshare) (4.67.1)
# Requirement already satisfied: openpyxl>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from akshare) (3.1.5)
# Collecting jsonpath>=0.82 (from akshare)
#   Downloading jsonpath-0.82.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.6 in /usr/local/lib/python3.10/dist-packages (from akshare) (0.9.0)
# Requirement already satisfied: decorator>=4.4.2 in /usr/local/lib/python3.10/dist-packages (from akshare) (4.4.2)
# Collecting py-mini-racer>=0.6.0 (from akshare)
#   Downloading py_mini_racer-0.6.0-py2.py3-none-manylinux1_x86_64.whl.metadata (8.7 kB)
# Collecting akracer>=0.0.13 (from akracer[py-mini-racer]>=0.0.13; platform_system == "Linux"->akshare)
#   Downloading akracer-0.0.13-py3-none-any.whl.metadata (2.8 kB)
# WARNING: akracer 0.0.13 does not provide the extra 'py-mini-racer'
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.9.1->akshare) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.0.1->akshare) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.0.1->akshare) (0.5.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.0.3->akshare) (2.0.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->akshare) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->akshare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->akshare) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->akshare) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->akshare) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->akshare) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->akshare) (2024.12.14)
# Downloading akshare-1.15.68-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.1 MB/s eta 0:00:00
# Downloading akracer-0.0.13-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 27.2 MB/s eta 0:00:00
# Downloading py_mini_racer-0.6.0-py2.py3-none-manylinux1_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 11.7 MB/s eta 0:00:00
# Building wheels for collected packages: jsonpath
#   Building wheel for jsonpath (setup.py) ... done
#   Created wheel for jsonpath: filename=jsonpath-0.82.2-py3-none-any.whl size=5615 sha256=35c66fcc11712cb62d66d0d2b4ea8d825c884edb31c05b21dcc2a81784e27c4d
#   Stored in directory: /root/.cache/pip/wheels/a2/e3/6a/59f241672f3221253b1236359b0a711dabb69795a006184398
# Successfully built jsonpath
# Installing collected packages: py-mini-racer, jsonpath, akracer, akshare
# Successfully installed akracer-0.0.13 akshare-1.15.68 jsonpath-0.82.2 py-mini-racer-0.6.0

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from IPython.display import HTML
def demo_text_image():
    # image=Image.open("Save_icon.png")
    # image_np=np.array(image)
    # plt.imshow(image_np)
    # plt.text(10,10,"this is TEXT",fontsize=12)
    # plt.savefig("output.png")
    # html_content=f'<br> <p>hello, are you OK!</p><br><img alt="picture" src="temp.png " > '
    # html=HTML(html_content)
    html=HTML(filename="gou2jian.html")
    html

if __name__ == "__main__":
    demo_text_image()

# %%
import sixyao
import re
import sqlite3
import akshare_plotly as akPlot
from IPython.display import Markdown, display
from ipywidgets import  widgets,Layout
from PIL import Image
def draw_daily_35(change):
    stockCode=stock_name_text.value
    dateOrigin=gua_date_text.value
    days=35
    imgfile=akPlot.drawDailyLine(stockCode,dateOrigin,time_period=days)
    pics_content="![]("+imgfile+")"
    output.clear_output()
    with output:
        display(Markdown(pics_content))
    # temp=stockCode+" ---   OK  ---  "  +dateOrigin +"    "+imgfile
    # with output:
    #     print(temp)

def draw_daily_15(change):
    stockCode=stock_name_text.value
    dateOrigin=gua_date_text.value
    days=15
    imgfile=akPlot.drawDailyLine(stockCode,dateOrigin,time_period=days)
    pics_content="![]("+imgfile+")"
    output.clear_output()
    with output:
        display(Markdown(pics_content))

def draw_daiqqly_365(change):
    stockCode=stock_name_text.value
    dateOrigin=gua_date_text.value
    imgfile=akPlot.drawMonthLine(stockCode,dateOrigin)
    pics_content="![]("+imgfile+")"
    output.clear_output()
    with output:
        display(Markdown(pics_content))

def paipan(change):
    day1=gua_date_text.value
    namestr=gua_name_text.value
    cont=sixyao.paipan(day1,namestr)
    temp=text_box.value+cont
    text_box.value=temp

def save_text(change):
    new_content = text_box.value
    new_stockCode= stock_name_text.value
    new_guaName=  gua_name_text.value
    new_guaDate= gua_date_text.value
    new_subject= subject_text.value
    id=slider1.value
    rowid=df.loc[id,'rowid']
    df.loc[id,'guaContent']=new_content
    connection = sqlite3.connect('Guas.db')
    cursor = connection.cursor()
    query='UPDATE StockGuas  SET guaDate="{}", stockName = "{}", guaName="{}", guaContent ="{}",guaSubject="{}" WHERE rowid = {}  '.format( new_guaDate, new_stockCode, new_guaName, new_content, new_subject, rowid)
    cursor.execute(query)
    connection.commit()
    cursor.close()
    connection.close()

def record_show(change):
    value=change['new']
    # print( f'当前数据编号: {value}')
    gua_name_text.value=df.loc[value,'guaName']
    gua_date_text.value=df.loc[value,'guaDate']
    stock_name_text.value=df.loc[value,'stockName']
    subject_text.value=df.loc[value,'subject']
    text_box.value=df.loc[value,'guaContent']
    # content=content.replace("\n","\n\n")
    #re1=r'images.+jpg|images.+.jpeg|images.+png'
    content=text_box.value
    re1=r'images.+jpg|images.+.jpeg|images.+png'
    images=re.findall(re1,content)
    pics_content=""
    for item in images:
        item1="https://64gua.github.io/"+item
        pics_content=pics_content+"![]("+item1+")"
    output.clear_output()
    with output:
        display(Markdown(pics_content))
        # for item in images:
        #     print(item)


length=df.shape[0]
print("df length=", length)
slider1 = widgets.IntSlider(value=0, min=0, max=length-1, description='卦例',layout=Layout(width='80%', height='20px'))
gua_name_text = widgets.Text(description='卦名:', layout=Layout(width='150px', height='20px'))
gua_date_text = widgets.Text(description='日期:', layout=Layout(width='150px', height='20px'))
stock_name_text = widgets.Text(description='股票:', layout=Layout(width='150px', height='20px'))
subject_text = widgets.Text(description='钥语:', layout=Layout(width='200px', height='20px'))
button_sixyao = widgets.Button(description='生成六爻', layout=Layout(width='100px', height='20px'))
button_draw15 = widgets.Button(description='绘图15天', layout=Layout(width='100px', height='20px'))
button_draw35 = widgets.Button(description='绘图35天', layout=Layout(width='100px', height='20px'))
button_draw365 = widgets.Button(description='绘图一年', layout=Layout(width='100px', height='20px'))
button_save_img = widgets.Button(description='图片存盘', layout=Layout(width='100px', height='20px'))
button_save_text = widgets.Button(description='保存修改', layout=Layout(width='100px', height='20px'))
text_box = widgets.Textarea(value='',placeholder='markdown内容', layout=Layout(width='100%', height='400px'))
# text_box = widgets.Textarea(value='',placeholder='markdown内容', layout=Layout(width='50%', height='400px'))
output=widgets.Output(layout=Layout(width='80%', height='500px'))
layout1=widgets.HBox([gua_name_text,gua_date_text])
layout2=widgets.HBox([stock_name_text,subject_text])
layout3=widgets.HBox([button_sixyao,button_save_text])
layout4=widgets.HBox([button_draw15,button_draw35,button_draw365,button_save_img ])
slider1.observe(record_show, names='value')
# slider2.observe(image_show,names='value')
button_sixyao.on_click(paipan)
button_save_text.on_click(save_text)
button_draw15.on_click(draw_daily_15)
button_draw35.on_click(draw_daily_35)
button_draw365.on_click(draw_daily_365)
# widgets.interact(format_slider, value=slider1)
# widgets.interact(image_show, value=slider2)
display(slider1, layout1 ,layout2,layout3,text_box,layout4,output)
# Out:
# df length= 14
# IntSlider(value=0, description='卦例', layout=Layout(height='20px', width='80%'), max=13)
# HBox(children=(Text(value='', description='卦名:', layout=Layout(height='20px', width='150px')), Text(value='', …
# HBox(children=(Text(value='', description='股票:', layout=Layout(height='20px', width='150px')), Text(value='', …
# HBox(children=(Button(description='生成六爻', layout=Layout(height='20px', width='100px'), style=ButtonStyle()), B…
# Textarea(value='', layout=Layout(height='400px', width='100%'), placeholder='markdown内容')
# HBox(children=(Button(description='绘图15天', layout=Layout(height='20px', width='100px'), style=ButtonStyle()), …
# Output(layout=Layout(height='500px', width='80%'))

# %%
# !run akshare_plotly.py
# Out:
# /bin/bash: line 1: run: command not found

# %%
# 最简单搜索程序，按卦名+干支+旬空，搜索相关记录到df
#下一个程序则显示各记录细节
import sqlite3
import pandas as pd

def loadinfo(gua_name_str,gangzhi_str,xunkong_str):
    database="Guas.db"
    connection=sqlite3.connect(database)
    query=f'select rowid, guaDate, guaName, stockName, substr(guaSubject,1,20) as subject, guaContent from StockGuas  where guaName like "{gua_name_str}"   '
    orderby= '  order by cast( substr(guaDate,6,2) as integer),guaDate '
    sub2=""
    sub3=""
    if gangzhi_str!="":
        sub2=f' and gangZhi like "%{gangzhi_str}%"  '
    if xunkong_str!="":
        sub3=f' and xunKong like "%{xunkong_str}%"  '
    query=query+sub2+sub3+orderby
    df=pd.read_sql_query(query,connection)
    return df
# df_disp=df[['rowid', 'guaDate','guaName','stockName','subject']]
# df_disp=df_disp.rename(columns = {'rowid':'记录号' ,'guaDate':'日期','guaName':'卦名','stockName':'股票','subject':'预测主题'})
gua_name_str=input("输入卦名:")
gangzhi_str=input("输入日月干支:")
xunkong_str=input("输入旬空:")
df=loadinfo(gua_name_str,gangzhi_str,xunkong_str)
df.head(10)
# Out:
# 输入卦名:复之屯
# 输入日月干支:
# 输入旬空:
#    rowid     guaDate guaName stockName               subject  \
# 0   4982  2020-03-23     复之屯    600252              手中一股下周涨跌
# 1   1870  2021-03-22     复之屯    600387         寻找志同道合的股票卦友合作
# 2  10825  2011-04-02     复之屯    000531          占000531辰月涨跌？
# 3  18605  2017-04-27     复之屯    601998  中信银行未来两个月如何走？ 复之屯。.m
# 4   4806  2020-04-20     复之屯        大盘  梅花小孩：四月月K数理卦  2743.5
# 5  21817  2024-04-16     复之屯    515220     煤炭ETF到七月中旬，复之屯.md
# 6   2096  2021-05-12     复之屯  sh000001              5月12日大盘？
# 7   1959  2021-06-10     复之屯  sh000001              6月10日大盘？
# 8  18420  2013-07-18     复之屯    002009         复之屯_002009.md
# 9  15830  2014-07-10     复之屯      NULL  复之屯，财化兄。占事：搜于特 711 两
#
#                                           guaContent
# 0  手中一股下周涨跌\n6252本周涨跌--手摇卦\n公历时间：2020年3月23日10时9分 ...
# 1  主帖标题: 寻找志同道合的股票卦友合作\n海越能源何时开始上升趋势\n起卦公历：2021年3...
# 2  主帖标题: 铜钱卦，高手请进，理论符合实际给50金币。请指点卦理\n占000531辰月涨跌？...
# 3  中信银行未来两个月如何走？ 复之屯。\n公历起卦时间：2017年4月27日10时46分　(电...
# 4  主题：4月黄金周K数理卦1679\n\r\n庚子 庚辰 癸巳 乙卯 (午未空) 庚子年三月廿...
# 5  天机六爻排盘\n2024年4月16日 21:12\n占问：煤炭ETF到七月中旬：少阳 少阴 ...
# 6  主帖标题: 5月12日大盘？\n2021年5月12日5时0分    农历时间：辛丑年 四月初...
# 7  主帖标题: 6月10日大盘？\n2021年6月10日6时45分    农历时间：辛丑年 五月...
# 8  占事：002009当天走势\n起卦方式：手工指定　　\n公历时间：2013年7月18日 9时...
# 9  占事：搜于特 711 两周 \n公历时间：2014年7月10日20时59分    \n干　　...

# %%
import pandas as pd
import re
import sqlite3
from IPython.display import Markdown, display
from ipywidgets import  widgets,Layout
from PIL import Image

def displayRecord(change):
    value=change['new']
    df=searchGua(change)
    text_box.value=str(len)
    # print( f'当前数据编号: {value}')
    content=df.loc[value,'guaContent']
    content=content.replace("\n","\n\n")
    text_box.value=content
    re1=r'images.+jpg|images.+.jpeg|images.+png'
    images=re.findall(re1,content)
    img_dropdown.options=images
    img_dropdown.index=1
    displayImage(change)

def displayImages(change):
    content=""
    for item in img_dropdown.options:
        content=content+"![]("+item+")"
    # content=img_dropdown.value
    # content="![]("+content+")"
    with output2:
        output2.clear_output()
        display(Markdown(content))
        # display(Image.open(content))

def searchGua(change):
    gua_name_str=gua_name_text.value
    database="Guas.db"
    connection=sqlite3.connect(database)
    # gua_name_str="泰静卦"
    query=f'select rowid, guaDate, guaName,stockName,substr(guaSubject,1,20),guaContent from StockGuas  where guaName like "{gua_name_str}"   '
    df=pd.read_sql_query(query,connection)
    df_display=df[['rowid', 'guaDate','guaName', 'stockName','substr(guaSubject,1,20)']]
    output1.clear_output( )
    output2.clear_output()
    text_box.value=""
    length=df.shape[0]
    slider.max=length
    with output1:
        print(df_display)
    connection.close()
    return df

slider = widgets.IntSlider(value=0, min=0, max=20, description='查询编号')
gua_name_text = widgets.Text(description='卦名:', layout=Layout(width='150px', height='20px'))
monthday_text = widgets.Text(description='日月:', layout=Layout(width='150px', height='20px'))
xunkong_text = widgets.Text(description='旬空:', layout=Layout(width='150px', height='20px'))
button_search = widgets.Button(description='搜索', layout=Layout(width='100px', height='20px'))
output1=widgets.Output(layout=Layout(width='80%', height='200px'))
output2=widgets.Output(layout=Layout(width='80%', height='200px'))

img_dropdown = widgets.Dropdown(discription='选择图片',layout=Layout(width='300px', height='20px'))
text_box = widgets.Textarea(value='',placeholder='markdown内容', layout=Layout(width='50%', height='400px'))

search_bar=widgets.HBox([button_search,gua_name_text,monthday_text,xunkong_text])
search_box=widgets.VBox([search_bar,output1])
image_box=widgets.VBox([img_dropdown,output2])
detail_box=widgets.HBox([text_box,image_box])
main_layout=widgets.VBox([search_box,slider,detail_box])
button_search.on_click(searchGua)
slider.observe(displayRecord,names='value')
img_dropdown.observe(displayImages,names='value')
# widgets.interact(displayRecord, value=slider)
# button_disp.on_click(displayRecord)
display(main_layout)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from IPython.display import HTML

image=Image.open("Save_icon.png")
image_np=np.array(image)
# # plt.imshow(image_np)
# plt.text(10,10,"this is TEXT",fontsize=12)
# plt.savefig("output.png")
html_content=f'<br> <p>hello, are you OK!</p><br><img alt="picture" src="temp.jpg " > '
# html=HTML(html_content)
html=HTML(filename="gou2jian.html")
html
